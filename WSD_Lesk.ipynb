# %%
import adagram
import gensim
import pandas as pd
from lxml import html
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
from pymorphy2 import MorphAnalyzer
from string import punctuation
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
morph = MorphAnalyzer()
punct = punctuation+'«»—…“”*№–'
stops = set(stopwords.words('english'))

# %%
def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split() if word and word not in stops]
    words = [morph.parse(word)[0].normal_form for word in words if word]

    return words

def tokenize(text):
    
    words = [word.strip(punct) for word in text.lower().split() if word and word not in stops]
    words = [word for word in words if word]

    return words

# %%
with open("corpus_eng.txt", "r", encoding="utf8") as file:
    corpus = file.read()

# %%
def split_into_sentences(text):
    text = text.replace("!!!","!<stop>")
    text = text.replace("?!","!<stop>")
    text = text.replace(". ",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("\n"," <stop>")
    sentences = text.split("<stop>")
    sentences = [s.strip() for s in sentences]
    return sentences

# %%
sentences = split_into_sentences(corpus)

# %%
sentences_with_break = []
for sentence in sentences:
    words = sentence.split(" ")
    for word in words:
        if word == "break":
            sentences_with_break.append(sentence)

# %%
len(sentences_with_break)
# Out:
# 352

# %%
# определения и примеры (нумерация с 1)
word = 'break'
num = 1
for synset in wn.synsets(word):
    print(str(num) + " " + word + ' - ' + synset.definition() + ' - ' + ' | '.join(synset.examples()))
    num += 1
# Out:
# 1 break - some abrupt occurrence that interrupts an ongoing activity - the telephone is an annoying interruption | there was a break in the action when a player was hurt
# 2 break - an unexpected piece of good luck - he finally got his big break
# 3 break - (geology) a crack in the earth's crust resulting from the displacement of one side with respect to the other - they built it right over a geological fault | he studied the faulting of the earth's crust
# 4 break - a personal or social separation (as between opposing factions) - they hoped to avoid a break in relations
# 5 break - a pause from doing something (as work) - we took a 10-minute break | he took time out to recuperate
# 6 break - the act of breaking something - the breakage was unavoidable
# 7 break - a time interval during which there is a temporary cessation of something -
# 8 break - breaking of hard tissue such as bone - it was a nasty fracture | the break seems to have been caused by a fall
# 9 break - the occurrence of breaking - the break in the dam threatened the valley
# 10 break - an abrupt change in the tone or register of the voice (as at puberty or due to emotion) - then there was a break in her voice
# 11 break - the opening shot that scatters the balls in billiards or pool -
# 12 break - (tennis) a score consisting of winning a game when your opponent was serving - he was up two breaks in the second set
# 13 break - an act of delaying or interrupting the continuity - it was presented without commercial breaks | there was a gap in his account
# 14 break - a sudden dash - he made a break for the open door
# 15 break - any frame in which a bowler fails to make a strike or spare - the break in the eighth frame cost him the match
# 16 break - an escape from jail - the breakout was carefully planned
# 17 break - terminate - She interrupted her pregnancy | break a lucky streak | break the cycle of poverty
# 18 break - become separated into pieces or fragments - The figurine broke | The freshly baked loaf fell apart
# 19 break - render inoperable or ineffective - You broke the alarm clock when you took it apart!
# 20 break - ruin completely - He busted my radio!
# 21 break - destroy the integrity of; usually by force; cause to separate into pieces or fragments - He broke the glass plate | She broke the match
# 22 break - act in disregard of laws, rules, contracts, or promises - offend all laws of humanity | violate the basic laws or human civilization | break a law | break a promise
# 23 break - move away or escape suddenly - The horses broke from the stable | Three inmates broke jail | Nobody can break out--this prison is high security
# 24 break - scatter or part - The clouds broke after the heavy downpour
# 25 break - force out or release suddenly and often violently something pent up - break into tears | erupt in anger
# 26 break - prevent completion - stop the project | break off the negotiations
# 27 break - enter someone's (virtual or real) property in an unauthorized manner, usually with the intent to steal or commit a violent act - Someone broke in while I was on vacation | They broke into my car and stole my radio! | who broke into my account last night?
# 28 break - make submissive, obedient, or useful - The horse was tough to break | I broke in the new intern
# 29 break - fail to agree with; be in violation of; as of rules or patterns - This sentence violates the rules of syntax
# 30 break - surpass in excellence - She bettered her own record | break a record
# 31 break - make known to the public information that was previously known only to a few people or that was meant to be kept a secret - The auction house would not disclose the price at which the van Gogh had sold | The actress won't reveal how old she is | bring out the truth | he broke the news to her | unwrap the evidence in the murder case
# 32 break - come into being - light broke over the horizon | Voices broke in the air
# 33 break - stop operating or functioning - The engine finally went | The car died on the road | The bus we travelled in broke down on the way to town | The coffee maker broke | The engine failed on the way to town | her eyesight went after the accident
# 34 break - interrupt a continued activity - She had broken with the traditional patterns
# 35 break - make a rupture in the ranks of the enemy or one's own by quitting or fleeing - The ranks broke
# 36 break - curl over and fall apart in surf or foam, of waves - The surf broke
# 37 break - lessen in force or effect - soften a shock | break a fall
# 38 break - be broken in - If the new teacher won't break, we'll add some stress
# 39 break - come to an end - The heat wave finally broke yesterday
# 40 break - vary or interrupt a uniformity or continuity - The flat plain was broken by tall mesas
# 41 break - cause to give up a habit - She finally broke herself of smoking cigarettes
# 42 break - give up - break cigarette smoking
# 43 break - come forth or begin from a state of latency - The first winter storm broke over New York
# 44 break - happen or take place - Things have been breaking pretty well for us in the past few months
# 45 break - cause the failure or ruin of - His peccadilloes finally broke his marriage | This play will either make or break the playwright
# 46 break - invalidate by judicial action - The will was broken
# 47 break - discontinue an association or relation; go different ways - The business partners broke over a tax question | The couple separated after 25 years of marriage | My friend and I split up
# 48 break - assign to a lower position; reduce in rank - She was demoted because she always speaks up | He was broken down to Sergeant
# 49 break - reduce to bankruptcy - My daughter's fancy wedding is going to break me! | The slump in the financial markets smashed him
# 50 break - change directions suddenly -
# 51 break - emerge from the surface of a body of water - The whales broke
# 52 break - break down, literally or metaphorically - The wall collapsed | The business collapsed | The dam broke | The roof collapsed | The wall gave in | The roof finally gave under the weight of the ice
# 53 break - do a break dance - Kids were break-dancing at the street corner
# 54 break - exchange for smaller units of money - I had to break a $100 bill just to buy the candy
# 55 break - destroy the completeness of a set of related items - The book dealer would not break the set
# 56 break - make the opening shot that scatters the balls -
# 57 break - separate from a clinch, in boxing - The referee broke the boxers
# 58 break - go to pieces - The lawn mower finally broke | The gears wore out | The old chair finally fell apart completely
# 59 break - break a piece from a whole - break a branch from a tree
# 60 break - become punctured or penetrated - The skin broke
# 61 break - pierce or penetrate - The blade broke her skin
# 62 break - be released or become known; of news - News of her death broke in the morning
# 63 break - cease an action temporarily - We pause for station identification | let's break for lunch
# 64 break - interrupt the flow of current in - break a circuit
# 65 break - undergo breaking - The simple vowels broke in many Germanic languages
# 66 break - find a flaw in - break an alibi | break down a proof
# 67 break - find the solution or key to - break the code
# 68 break - change suddenly from one tone quality or register to another - Her voice broke to a whisper when she started to talk about her children
# 69 break - happen - Report the news as it develops | These political movements recrudesce from time to time
# 70 break - become fractured; break or crack on the surface only - The glass cracked when it was heated
# 71 break - crack; of the male voice in puberty - his voice is breaking--he should no longer sing in the choir
# 72 break - fall sharply - stock prices broke
# 73 break - fracture a bone of - I broke my foot while playing hockey
# 74 break - diminish or discontinue abruptly - The patient's fever broke last night
# 75 break - weaken or destroy in spirit or body - His resistance was broken | a man broken by the terrible experience of near-death

# %%
from random import sample
chosen_sentences = sample(sentences_with_break, k = 10)
my_sentences = []
for sentence in chosen_sentences:
    sentence = sentence.split(" ")
    my_sentences.append(sentence)

# %%
for sentence in my_sentences:
    print(" ".join(sentence))
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming.
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car.
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired.
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel.
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché.
#
# 20): You have to break some promises, but it's for a good cause.
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C..
#
# Study hard, but be sure to have a break time to time.
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch .
#
# "He was thinking that people were out to kill him, out to break him and Kim up.

# %%
# пропишу ручками, какое значение в каждом предложении
my_answer = [33, 25, 5, 5, 37, 22, 13, 5, 8, 4]

# %% [markdown]
# ### Попытка 1. При таком алгоритме Леска (пересечение предложений и определений) результат 0/10, потому что в определениях нет слов, которые встречаются в предложениях.

# %%
# версия с объединением дефиниций и предложений
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        definition = tokenize(synset.definition())
        definition = set(definition)
        sentence = set(sentence)
        overlap = len(definition & sentence)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1 # так как я размечала по смыслам с нумерацией с 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 52 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 52 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 7 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 52 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 29 37
#
# 20): You have to break some promises, but it's for a good cause. 2 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 29 13
#
# Study hard, but be sure to have a break time to time. 7 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 52 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 31 4

# %% [markdown]
# ### Попытка 2. При пересечении предложений и примеров результат 2/10, хотя в примерах есть полное пересечение фразы commercial break, которое не попало в удачные - очень странно

# %%
# версия с объединением дефиниций и предложений
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        examples = tokenize(" ".join(synset.examples()))
        examples = set(examples)
        sentence = set(sentence)
        overlap = len(examples & sentence)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 31 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 1 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 5 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 1 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 5 37
#
# 20): You have to break some promises, but it's for a good cause. 1 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 5 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 1 4

# %% [markdown]
# ### Попытка 3. Пробую нормализовать все слова в предложении и примерах, а потом применить версию Леска с пересечением предложений и примеров - результат 2/10.  При нормализации выкидываю стоп-слова. Как оказалось, функция нормализации, которую я брала из ноутбука-примера, была для русского языка - то есть нет различий с предыдущей попыткой. Ниже пробую с нормализацией для английского.

# %%
# версия с объединением примеров и предложений
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        examples = normalize(" ".join(synset.examples()))
        examples = set(examples)
        sentence = set(normalize(" ".join(sentence)))
        overlap = len(examples & sentence)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 31 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 1 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 5 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 1 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 5 37
#
# 20): You have to break some promises, but it's for a good cause. 1 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 5 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 1 4

# %% [markdown]
# ### Попытка 4. Пересеку предложения с определениями и примерами, нормализовав слова - результат 2/10. Нормализация все так же на русском - мой промах, который я заметила только потом.

# %%
# версия с объединением примеров, определений и предложений
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        definition = normalize(synset.definition())
        definition = set(definition)
        examples = normalize(" ".join(synset.examples()))
        examples = set(examples)
        sentence = set(normalize(" ".join(sentence)))
        overlap = len(sentence & (examples | definition))
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 31 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 52 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 5 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 1 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 5 37
#
# 20): You have to break some promises, but it's for a good cause. 2 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 5 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 52 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 1 4

# %% [markdown]
# ### Попытка 5. Надо посмотреть по окну размера 3 в предложениях и примерах. Результат 1/10 (но тот, который раньше неправильно определялся) - в окне совпал контекст break up

# %%
def get_words_in_context(sentence, window):
    words_in_context = []
    if type(sentence) == list:
        words = sentence
    else:
        words = sentence.split(" ")
    for index, word in enumerate(words):
        if word == "break":
            words_in_context.append(word)
            for word in words[max(0, index - window): index] + words[index + 1: index + window + 1]:
                words_in_context.append(word)
    return words_in_context

# %%
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        examples = " ".join(synset.examples()).split()
        examples_context = set(get_words_in_context(examples, 3))
        sentence_context = set(get_words_in_context(sentence, 3))
        overlap = len(sentence_context & examples_context)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 55 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 1 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 4 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 14 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 1 37
#
# 20): You have to break some promises, but it's for a good cause. 8 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 5 13
#
# Study hard, but be sure to have a break time to time. 4 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 4 4

# %% [markdown]
# ### Попытка 6. Окно размера 4 - результат 1/10. Все тот же break up из примера.

# %%
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        examples = " ".join(synset.examples())
        examples_context = set(get_words_in_context(examples, 4))
        sentence_context = set(get_words_in_context(sentence, 4))
        overlap = len(sentence_context & examples_context)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 55 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 1 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 4 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 14 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 1 37
#
# 20): You have to break some promises, but it's for a good cause. 8 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 8 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 4 4

# %% [markdown]
# ### Попытка 7. Не буду в нормализации выкидывать стоп-слова (я все еще не заметила, что нормализатор для русского). Окно размера 4. Результат 1/10

# %%
# поправлю нормализацию - не буду выкидывать стоп-слова
def normalise(words):
    words = [morph.parse(word)[0].normal_form for word in words]

    return words

# %%
morph.parse('finished')
# Out:
# [Parse(word='finished', tag=OpencorporaTag('LATN'), normal_form='finished', score=1.0, methods_stack=((<LatinAnalyzer>, 'finished'),))]

# %%
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    
    for i, synset in enumerate(wn.synsets(word)):
        examples = " ".join(synset.examples())
        examples_context = set(normalise(get_words_in_context(examples, 4)))
        sentence_context = set(normalise(get_words_in_context(sentence, 4)))
        overlap = len(sentence_context & examples_context)
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 55 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 1 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 4 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 14 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 1 37
#
# 20): You have to break some promises, but it's for a good cause. 8 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 8 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 4 4

# %% [markdown]
# ### Попытка 8. Вариант с коэффициентами. Уже используется нормализатор для английского (чуть ниже написан). Результат 1/10

# %%
from collections import Counter

# %%
word_counter = Counter()
for el in wn.synsets('break'):
    word_counter += Counter(normaliser(el.definition().split()))
    for ex in el.examples():
        word_counter += Counter(normaliser(ex.split()))
#word_counter['break'] = 0
#word_counter += Counter()

# %%
word_counter['break']
# Out:
# 84

# %%
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    overlap = 0
    for i, synset in enumerate(wn.synsets(word)):
        overlap = 0
        examples = " ".join(synset.examples())
        examples_context = set(normalise(get_words_in_context(examples, 4)))
        
        sentence_context = set(normalise(get_words_in_context(sentence, 4)))
        
        for el in sentence_context:
            if el != 'break':
                if el in examples_context:
                    try:
                        if word_counter[el] > 1:
                            overlap += 1 / word_counter[el]
                    except:
                        print(el)
        # overlap = len(sentence_context & examples_context)
        
        if overlap > maxoverlap:
            maxoverlap = overlap
            bestsense = i + 1
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 55 33
#
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 5 25
#
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 4 5
#
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 14 5
#
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 1 37
#
# 20): You have to break some promises, but it's for a good cause. 8 22
#
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 1 13
#
# Study hard, but be sure to have a break time to time. 5 5
#
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 1 8
#
# "He was thinking that people were out to kill him, out to break him and Kim up. 5 4

# %% [markdown]
# ### Вот он, нормализатор для английского!

# %%
import spacy
nlp = spacy.load('en')

# %%
def normaliser(words):
    words = [token.lemma_ for token in nlp(" ".join(words))]
    return words

# %%
normaliser(["finished,", "minutes", '23'])
# Out:
# ['finish', ',', 'minute', '23']

# %%
word_counter
# Out:
# Counter({'some': 2,
#          'abrupt': 2,
#          'occurrence': 2,
#          'that': 5,
#          'interrupt': 6,
#          'an': 11,
#          'ongoing': 1,
#          'activity': 2,
#          'the': 116,
#          'telephone': 1,
#          'be': 34,
#          'annoying': 1,
#          'interruption': 1,
#          'there': 4,
#          'a': 51,
#          'break': 84,
#          'in': 37,
#          'action': 3,
#          'when': 5,
#          'player': 1,
#          'hurt': 1,
#          'unexpected': 1,
#          'piece': 5,
#          'of': 35,
#          'good': 1,
#          'luck': 1,
#          '-PRON-': 68,
#          'finally': 8,
#          'get': 1,
#          'big': 1,
#          '(': 6,
#          'geology': 1,
#          ')': 6,
#          'crack': 4,
#          'earth': 2,
#          "'s": 6,
#          'crust': 2,
#          'result': 1,
#          'from': 11,
#          'displacement': 1,
#          'one': 3,
#          'side': 1,
#          'with': 4,
#          'respect': 1,
#          'to': 30,
#          'other': 1,
#          'build': 1,
#          'right': 1,
#          'over': 5,
#          'geological': 1,
#          'fault': 1,
#          'study': 1,
#          'faulting': 1,
#          'personal': 1,
#          'or': 41,
#          'social': 1,
#          'separation': 1,
#          'as': 6,
#          'between': 1,
#          'oppose': 1,
#          'faction': 1,
#          'hop': 1,
#          'avoid': 1,
#          'relation': 2,
#          'pause': 2,
#          'do': 2,
#          'something': 4,
#          'work': 1,
#          'take': 4,
#          '10-minute': 1,
#          'time': 4,
#          'out': 5,
#          'recuperate': 1,
#          'act': 4,
#          'breakage': 1,
#          'unavoidable': 1,
#          'interval': 1,
#          'during': 1,
#          'which': 3,
#          'temporary': 1,
#          'cessation': 1,
#          'hard': 1,
#          'tissue': 1,
#          'such': 1,
#          'bone': 2,
#          'nasty': 1,
#          'fracture': 2,
#          'seem': 1,
#          'have': 5,
#          'cause': 1,
#          'by': 6,
#          'fall': 6,
#          'breaking': 2,
#          'dam': 2,
#          'threaten': 1,
#          'valley': 1,
#          'change': 3,
#          'tone': 2,
#          'register': 2,
#          'voice': 6,
#          'at': 3,
#          'puberty': 2,
#          'due': 1,
#          'emotion': 1,
#          'then': 1,
#          'opening': 2,
#          'shot': 2,
#          'scatter': 3,
#          'ball': 2,
#          'billiard': 1,
#          'pool': 1,
#          'tennis': 1,
#          'score': 1,
#          'consist': 1,
#          'win': 1,
#          'game': 1,
#          'opponent': 1,
#          'serve': 1,
#          'up': 6,
#          'two': 1,
#          'second': 1,
#          'set': 3,
#          'delay': 1,
#          'continuity': 2,
#          'present': 1,
#          'without': 1,
#          'commercial': 1,
#          'gap': 1,
#          'account': 2,
#          'sudden': 1,
#          'dash': 1,
#          'make': 7,
#          'for': 5,
#          'open': 1,
#          'door': 1,
#          'any': 1,
#          'frame': 2,
#          'bowler': 1,
#          'fail': 3,
#          'strike': 1,
#          'spare': 1,
#          'eighth': 1,
#          'cost': 1,
#          'match': 2,
#          'escape': 2,
#          'jail': 2,
#          'breakout': 1,
#          'carefully': 1,
#          'plan': 1,
#          'terminate': 1,
#          'pregnancy': 1,
#          'lucky': 1,
#          'streak': 1,
#          'cycle': 1,
#          'poverty': 1,
#          'become': 4,
#          'separated': 1,
#          'into': 6,
#          'fragment': 2,
#          'figurine': 1,
#          'freshly': 1,
#          'baked': 1,
#          'loaf': 1,
#          'apart': 4,
#          'render': 1,
#          'inoperable': 1,
#          'ineffective': 1,
#          'alarm': 1,
#          'clock': 1,
#          '!': 4,
#          'ruin': 2,
#          'completely': 2,
#          'bust': 1,
#          'radio': 2,
#          'destroy': 3,
#          'integrity': 1,
#          ';': 9,
#          'usually': 2,
#          'force': 3,
#          'because': 4,
#          'separate': 3,
#          'glass': 2,
#          'plate': 1,
#          'disregard': 1,
#          'law': 4,
#          ',': 10,
#          'rule': 3,
#          'contract': 1,
#          'promise': 2,
#          'offend': 1,
#          'all': 1,
#          'humanity': 1,
#          'violate': 2,
#          'basic': 1,
#          'human': 1,
#          'civilization': 1,
#          'move': 1,
#          'away': 1,
#          'suddenly': 4,
#          'horse': 2,
#          'stable': 1,
#          'three': 1,
#          'inmate': 1,
#          'nobody': 1,
#          'can': 1,
#          '--': 2,
#          'this': 3,
#          'prison': 1,
#          'high': 1,
#          'security': 1,
#          'part': 1,
#          'cloud': 1,
#          'after': 3,
#          'heavy': 1,
#          'downpour': 1,
#          'release': 2,
#          'and': 4,
#          'often': 1,
#          'violently': 1,
#          'pen': 1,
#          'tear': 1,
#          'erupt': 1,
#          'anger': 1,
#          'prevent': 1,
#          'completion': 1,
#          'stop': 2,
#          'project': 1,
#          'off': 1,
#          'negotiation': 1,
#          'enter': 1,
#          'someone': 2,
#          'virtual': 1,
#          'real': 1,
#          'property': 1,
#          'unauthorized': 1,
#          'manner': 1,
#          'intent': 1,
#          'steal': 2,
#          'commit': 1,
#          'violent': 1,
#          'while': 2,
#          'on': 5,
#          'vacation': 1,
#          'car': 2,
#          'who': 1,
#          'last': 2,
#          'night': 2,
#          '?': 1,
#          'submissive': 1,
#          'obedient': 1,
#          'useful': 1,
#          'tough': 1,
#          'new': 3,
#          'intern': 1,
#          'agree': 1,
#          'violation': 1,
#          'pattern': 2,
#          'sentence': 1,
#          'syntax': 1,
#          'surpass': 1,
#          'excellence': 1,
#          'better': 1,
#          'own': 2,
#          'record': 2,
#          'know': 2,
#          'public': 1,
#          'information': 1,
#          'previously': 1,
#          'only': 2,
#          'few': 2,
#          'people': 1,
#          'mean': 1,
#          'keep': 1,
#          'secret': 1,
#          'auction': 1,
#          'house': 1,
#          'would': 2,
#          'not': 4,
#          'disclose': 1,
#          'price': 2,
#          'van': 1,
#          'gogh': 1,
#          'sell': 1,
#          'actress': 1,
#          'will': 5,
#          'reveal': 1,
#          'how': 1,
#          'old': 2,
#          'bring': 1,
#          'truth': 1,
#          'news': 4,
#          'unwrap': 1,
#          'evidence': 1,
#          'murder': 1,
#          'case': 1,
#          'come': 3,
#          'light': 1,
#          'horizon': 1,
#          'air': 1,
#          'operate': 1,
#          'function': 1,
#          'engine': 2,
#          'go': 5,
#          'die': 1,
#          'road': 1,
#          'bus': 1,
#          'travel': 1,
#          'down': 4,
#          'way': 3,
#          'town': 2,
#          'coffee': 1,
#          'maker': 1,
#          'eyesight': 1,
#          'accident': 1,
#          'continue': 1,
#          'traditional': 1,
#          'rupture': 1,
#          'rank': 3,
#          'enemy': 1,
#          'quit': 1,
#          'flee': 1,
#          'curl': 1,
#          'surf': 2,
#          'foam': 1,
#          'wave': 2,
#          'lessen': 1,
#          'effect': 1,
#          'soften': 1,
#          'shock': 1,
#          'if': 1,
#          'teacher': 1,
#          'add': 1,
#          'stress': 1,
#          'end': 1,
#          'heat': 1,
#          'yesterday': 1,
#          'vary': 1,
#          'uniformity': 1,
#          'flat': 1,
#          'plain': 1,
#          'tall': 1,
#          'mesas': 1,
#          'give': 4,
#          'habit': 1,
#          'smoke': 1,
#          'cigarette': 2,
#          'smoking': 1,
#          'forth': 1,
#          'begin': 1,
#          'state': 1,
#          'latency': 1,
#          'first': 1,
#          'winter': 1,
#          'storm': 1,
#          'york': 1,
#          'happen': 2,
#          'place': 1,
#          'thing': 1,
#          'pretty': 1,
#          'well': 1,
#          'past': 1,
#          'month': 1,
#          'failure': 1,
#          'peccadillo': 1,
#          'marriage': 2,
#          'play': 2,
#          'either': 1,
#          'playwright': 1,
#          'invalidate': 1,
#          'judicial': 1,
#          'discontinue': 2,
#          'association': 1,
#          'different': 1,
#          'business': 2,
#          'partner': 1,
#          'tax': 1,
#          'question': 1,
#          'couple': 1,
#          '25': 1,
#          'year': 1,
#          'friend': 1,
#          'split': 1,
#          'assign': 1,
#          'low': 1,
#          'position': 1,
#          'reduce': 2,
#          'demote': 1,
#          'always': 1,
#          'speak': 1,
#          'sergeant': 1,
#          'bankruptcy': 1,
#          'daughter': 1,
#          'fancy': 1,
#          'wedding': 1,
#          'slump': 1,
#          'financial': 1,
#          'market': 1,
#          'smash': 1,
#          'direction': 1,
#          'emerge': 1,
#          'surface': 2,
#          'body': 2,
#          'water': 1,
#          'whale': 1,
#          'literally': 1,
#          'metaphorically': 1,
#          'wall': 2,
#          'collapse': 3,
#          'roof': 2,
#          'under': 1,
#          'weight': 1,
#          'ice': 1,
#          'dance': 1,
#          'kid': 1,
#          '-': 2,
#          'dancing': 1,
#          'street': 1,
#          'corner': 1,
#          'exchange': 1,
#          'small': 1,
#          'unit': 1,
#          'money': 1,
#          '$': 1,
#          '100': 1,
#          'bill': 1,
#          'just': 1,
#          'buy': 1,
#          'candy': 1,
#          'completeness': 1,
#          'related': 1,
#          'item': 1,
#          'book': 1,
#          'dealer': 1,
#          'clinch': 1,
#          'boxing': 1,
#          'referee': 1,
#          'boxer': 1,
#          'lawn': 1,
#          'mower': 1,
#          'gear': 1,
#          'wear': 1,
#          'chair': 1,
#          'whole': 1,
#          'branch': 1,
#          'tree': 1,
#          'punctured': 1,
#          'penetrate': 2,
#          'skin': 2,
#          'pierce': 1,
#          'blade': 1,
#          'known': 1,
#          'death': 2,
#          'morning': 1,
#          'cease': 1,
#          'temporarily': 1,
#          'station': 1,
#          'identification': 1,
#          'let': 1,
#          'lunch': 1,
#          'flow': 1,
#          'current': 1,
#          'circuit': 1,
#          'undergo': 1,
#          'simple': 1,
#          'vowel': 1,
#          'many': 1,
#          'germanic': 1,
#          'language': 1,
#          'find': 2,
#          'flaw': 1,
#          'alibi': 1,
#          'proof': 1,
#          'solution': 1,
#          'key': 1,
#          'code': 1,
#          'quality': 1,
#          'another': 1,
#          'whisper': 1,
#          'start': 1,
#          'talk': 1,
#          'about': 1,
#          'child': 1,
#          'report': 1,
#          'develop': 1,
#          'these': 1,
#          'political': 1,
#          'movement': 1,
#          'recrudesce': 1,
#          'fractured': 1,
#          'heated': 1,
#          'male': 1,
#          'should': 1,
#          'no': 1,
#          'longer': 1,
#          'sing': 1,
#          'choir': 1,
#          'sharply': 1,
#          'stock': 1,
#          'foot': 1,
#          'hockey': 1,
#          'diminish': 1,
#          'abruptly': 1,
#          'patient': 1,
#          'fever': 1,
#          'weaken': 1,
#          'spirit': 1,
#          'resistance': 1,
#          'man': 1,
#          'terrible': 1,
#          'experience': 1,
#          'near': 1})

# %% [markdown]
# ### Попытка 9. Нормализация для английского, окно по предложениям размера 6, а для пересечения - примеры и определения. Результат - 2/10, наконец-то определился правильно пример с commercial break.

# %%
def lesk(word, sentence):
    bestsense = 0
    maxoverlap = 0
    overlap = 0
    secmax = 0
    secmaxi = 0
    for i, synset in enumerate(wn.synsets(word)):
        overlap = 0
        
        examples = " ".join(synset.examples())
        #examples_context = set(normaliser(get_words_in_context(examples, 4)))
        
        examples_context = set(normaliser(examples.split()) + normaliser(synset.definition().split()))
        sentence_context = set(normaliser(get_words_in_context(sentence, 6)))

        for el in sentence_context:
            if el != 'break' and el != '-PRON-':
                if el in examples_context:
                    try:
                        if word_counter[el] > 0 :
                            overlap += 1 / word_counter[el]
                          #  print(el, end=' ')
                    except:
                        print(el)

    
        if overlap > maxoverlap:
            secmax = overlap
            secmaxi = bestsense
            
            maxoverlap = overlap
            bestsense = i + 1
            
        elif overlap > secmax:
            secmax = overlap
            secmaxi = i + 1
            
    print(secmaxi)
            
    return bestsense

# %%
index = 0
for sentence in my_sentences:
    print(" ".join(sentence), lesk("break", sentence), my_answer[index])
    index += 1
    print()
# Out:
# 31
# Sometimes the old Dell computers used by the officers would break down, and I'd just have to sit there, on a metal chair, staring at George Bush and Dick Cheney's pictures hanging on the wall and fuming. 54 33
#
# 5
# The race was also delayed on the 21st stage for almost a half hour when Eric Camilli rolled his Ford onto its roof, causing a fire to break out in the car. 8 25
#
# 2
# When that set amount of time is over, take a 20-30 minute break to keep your mind from getting tired. 31 5
#
# 10
# Win a fabulous UK break for two at Cliveden House Hotel Brought to you by 7 November 2016 • 7:30am Enter the prize draw before Friday 2 December and you and a friend could soon be enjoying a luxurious break at Cliveden House Hotel. 12 5
#
# 5
# Of course, if you remember "Bizarre Love Triangle" for one thing, it's that wallop of a chorus, hopping up and down the octave: "Every time I see you falling / I get down on my knees and pray." The quasi-religious wording gives it echoes of Al Green, and the melody is classic Motown, but the imagery of it is vague enough that it doesn't break the song's enigmatic spell with lyrical or musical cliché. 53 37
#
# 22
# 20): You have to break some promises, but it's for a good cause. 38 22
#
# 7
# — Larry Wilmore (@larrywilmore) November 28, 2016 Also on HuffPost Obama On Late-Night TV Obama On Late-Night TV 1 of 16 Barack Obama, Jimmy Fallon President Barack Obama sits with Jimmy Fallon during commercial break as he participates in a taping of the Jimmy Fallon Show, Tuesday, April 24, 2012, at the University of North Carolina at Chapel Hill, N.C.. 13 13
#
# 3
# Study hard, but be sure to have a break time to time. 5 5
#
# 7
# (Photo: Michael Loccisano/Getty Images) More Ethan talked about how Ryder gave him his break in Reality Bites during a 2014 interview on IMDb: What to Watch . 31 8
#
# 5
# "He was thinking that people were out to kill him, out to break him and Kim up. 25 4

# %% [markdown]
# ### Итого в разных комбинациях были правильно определены предложения 3, 7, 8 и 10. Странно, что ни разу не определилось правильно предложение 6 - там есть break promises, что упоминается в определении.
